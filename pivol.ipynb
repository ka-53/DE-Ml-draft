# %%
import numpy as n 
import pandas as p

# %%
pwd
# Out:
# '/Users/ka53/Desktop/transfer-football'

# %%
df = p.read_csv('/Users/ka53/Desktop/Football Data Archive/players.csv')

# %%
df
# Out:
#        player_id first_name     last_name                name  last_season  \
# 0             10   Miroslav         Klose      Miroslav Klose         2015
# 1             26      Roman  Weidenfeller  Roman Weidenfeller         2017
# 2             65    Dimitar      Berbatov    Dimitar Berbatov         2015
# 3             77        NaN         Lúcio               Lúcio         2012
# 4             80        Tom        Starke          Tom Starke         2017
# ...          ...        ...           ...                 ...          ...
# 32424    1306131      Fábio         Sambú         Fábio Sambú         2024
# 32425    1306851      Hakim      Sulemana      Hakim Sulemana         2024
# 32426    1309504     Diallo      Sanoussi     Diallo Sanoussi         2024
# 32427    1309800     Issaka         Seidu        Issaka Seidu         2024
# 32428    1319047    Oğulcan         Başol       Oğulcan Başol         2024
#
# ...

# %%
df.columns
# Out:
# Index(['player_id', 'first_name', 'last_name', 'name', 'last_season',
#        'current_club_id', 'player_code', 'country_of_birth', 'city_of_birth',
#        'country_of_citizenship', 'date_of_birth', 'sub_position', 'position',
#        'foot', 'height_in_cm', 'contract_expiration_date', 'agent_name',
#        'image_url', 'url', 'current_club_domestic_competition_id',
#        'current_club_name', 'market_value_in_eur',
#        'highest_market_value_in_eur'],
#       dtype='object')

# %%
p.pivot_table(df,index='name',values=['position','current_club_name','market_value_in_eur'],aggfunc=sum,fill_value=0).head(20)
# Out:
# /var/folders/zb/zdxx2l0s57103ycrdj0qmmkc0000gn/T/ipykernel_31466/4058878473.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   p.pivot_table(df,index='name',values=['position','current_club_name','market_value_in_eur'],aggfunc=sum,fill_value=0).head(20)
#                                                        current_club_name  \
# name
# A.J. Soares                                    Aarhus Gymnastik Forening
# AJ Leitch-Smith                                     Dundee Football Club
# Aaron Appindangoyé                                      Sivasspor Kulübü
# Aaron Bastiaans                                                VVV-Venlo
# Aaron Boupendza                                  Hatayspor Futbol Kulübü
# Aaron Brown                                     Kilmarnock Football Club
# ...

# %%
df
# Out:
#        player_id first_name     last_name                name  last_season  \
# 0             10   Miroslav         Klose      Miroslav Klose         2015
# 1             26      Roman  Weidenfeller  Roman Weidenfeller         2017
# 2             65    Dimitar      Berbatov    Dimitar Berbatov         2015
# 3             77        NaN         Lúcio               Lúcio         2012
# 4             80        Tom        Starke          Tom Starke         2017
# ...          ...        ...           ...                 ...          ...
# 32424    1306131      Fábio         Sambú         Fábio Sambú         2024
# 32425    1306851      Hakim      Sulemana      Hakim Sulemana         2024
# 32426    1309504     Diallo      Sanoussi     Diallo Sanoussi         2024
# 32427    1309800     Issaka         Seidu        Issaka Seidu         2024
# 32428    1319047    Oğulcan         Başol       Oğulcan Başol         2024
#
# ...

# %%
filtredv = df[df['highest_market_value_in_eur'] >= 80000000.0] #highest_market_value_in_eur

# %%
filtredv
# Out:
#        player_id first_name          last_name                name  \
# 758         8198        NaN  Cristiano Ronaldo   Cristiano Ronaldo
# 1385       16306        NaN           Casemiro            Casemiro
# 2225       26399     Sergio             Agüero       Sergio Agüero
# 2347       28003     Lionel              Messi        Lionel Messi
# 2658       31909       Toni              Kroos          Toni Kroos
# ...          ...        ...                ...                 ...
# 27270     648195       Enzo          Fernández      Enzo Fernández
# 27443     655488    Gabriel         Martinelli  Gabriel Martinelli
# 27978     683840        NaN              Pedri               Pedri
# 28056     687626     Moisés            Caicedo      Moisés Caicedo
# 31105     937958        NaN       Lamine Yamal        Lamine Yamal
#
#        last_season  current_club_id         player_code    country_of_birth  \
# 758           2022              985   cristiano-ronaldo            Portugal
# ...

# %%
p.pivot_table(filtredv,index='name',values=['position','current_club_name','market_value_in_eur'],aggfunc=max,fill_value=0).head(50)
# Out:
# /var/folders/zb/zdxx2l0s57103ycrdj0qmmkc0000gn/T/ipykernel_31466/3290959858.py:1: FutureWarning: The provided callable <built-in function max> is currently using DataFrameGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   p.pivot_table(filtredv,index='name',values=['position','current_club_name','market_value_in_eur'],aggfunc=max,fill_value=0).head(50)
#                                                 current_club_name  \
# name
# Alexis Mac Allister                       Liverpool Football Club
# Alisson                                   Liverpool Football Club
# Alphonso Davies                                 FC Bayern München
# Andrew Robertson                          Liverpool Football Club
# Ansu Fati                                   Futbol Club Barcelona
# Antoine Griezmann                  Club Atlético de Madrid S.A.D.
# ...

# %%
players_of_RM = df[df['current_club_name'] == 'Real Madrid Club de Fútbol'] # all players of madrid

# %%
p.pivot_table(players_of_RM,index='name',values=['position','current_club_name','market_value_in_eur'],aggfunc='min',fill_value=0)
# Out:
#                               current_club_name  market_value_in_eur  \
# name
# Andriy Lunin         Real Madrid Club de Fútbol           25000000.0
# Antonio Rüdiger      Real Madrid Club de Fútbol           25000000.0
# Arda Güler           Real Madrid Club de Fútbol           45000000.0
# Aurélien Tchouaméni  Real Madrid Club de Fútbol          100000000.0
# Brahim Díaz          Real Madrid Club de Fútbol           40000000.0
# Dani Ceballos        Real Madrid Club de Fútbol            4000000.0
# Daniel Carvajal      Real Madrid Club de Fútbol           12000000.0
# David Alaba          Real Madrid Club de Fútbol           15000000.0
# Derik Osede          Real Madrid Club de Fútbol             100000.0
# Diego Altube         Real Madrid Club de Fútbol             800000.0
# Diego Piñeiro        Real Madrid Club de Fútbol              50000.0
# Eden Hazard          Real Madrid Club de Fútbol            5000000.0
# ...

# %%
pwd
# Out:
# '/Users/ka53/Desktop/transfer-football'

# %%
df1 = p.read_csv('/Users/ka53/Desktop/Football Data Archive/transfers.csv')

# %%
df1
# Out:
#        player_id transfer_date transfer_season  from_club_id  to_club_id  \
# 0         195778    2026-06-30           25/26            79          27
# 1         569033    2026-06-30           25/26            39          27
# 2         626913    2026-06-30           25/26           398         380
# 3        1047109    2026-06-30           25/26          2672         265
# 4         302215    2025-12-31           25/26           279          86
# ...          ...           ...             ...           ...         ...
# 78151      35207    1995-07-01           95/96         42281       11896
# 78152      22141    1994-07-01           94/95         59178       29463
# 78153      33829    1994-07-01           94/95         58405       53957
# 78154      40680    1994-07-01           94/95         47320       47318
# 78155      61989    1993-07-01           93/94         55345       55343
#
#         from_club_name     to_club_name  transfer_fee  market_value_in_eur  \
# ...
