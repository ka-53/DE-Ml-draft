# %%
import numpy as n 
import pandas as p

# %%
pwd
# Out:
# '/Users/ka53/Desktop/transfer-football'

# %%
players = p.read_csv('/Users/ka53/Desktop/Football Data Archive/players.csv')
club_games = p.read_csv('/Users/ka53/Desktop/Football Data Archive/club_games.csv')
clubs = p.read_csv('/Users/ka53/Desktop/Football Data Archive/clubs.csv')
competitions = p.read_csv('/Users/ka53/Desktop/Football Data Archive/competitions.csv')
lineups = p.read_csv('/Users/ka53/Desktop/Football Data Archive/game_lineups.csv')
games = p.read_csv('/Users/ka53/Desktop/Football Data Archive/games.csv')
transfers = p.read_csv('/Users/ka53/Desktop/Football Data Archive/transfers.csv')

# %% [markdown]
# [text](<../Football Data Archive/appearances.csv>) [text](<../Football Data Archive/club_games.csv>) [text](<../Football Data Archive/clubs.csv>) [text](<../Football Data Archive/competitions.csv>) [text](<../Football Data Archive/game_events.csv>) [text](<../Football Data Archive/game_lineups.csv>) [text](<../Football Data Archive/games.csv>) [text](<../Football Data Archive/player_valuations.csv>) [text](<../Football Data Archive/players.csv>) [text](<../Football Data Archive/transfers.csv>)

# %%
players.columns
# Out:
# Index(['player_id', 'first_name', 'last_name', 'name', 'last_season',
#        'current_club_id', 'player_code', 'country_of_birth', 'city_of_birth',
#        'country_of_citizenship', 'date_of_birth', 'sub_position', 'position',
#        'foot', 'height_in_cm', 'contract_expiration_date', 'agent_name',
#        'image_url', 'url', 'current_club_domestic_competition_id',
#        'current_club_name', 'market_value_in_eur',
#        'highest_market_value_in_eur'],
#       dtype='object')

# %%
club_games.columns
# Out:
# Index(['game_id', 'club_id', 'own_goals', 'own_position', 'own_manager_name',
#        'opponent_id', 'opponent_goals', 'opponent_position',
#        'opponent_manager_name', 'hosting', 'is_win'],
#       dtype='object')

# %%
clubs.columns
# Out:
# Index(['club_id', 'club_code', 'name', 'domestic_competition_id',
#        'total_market_value', 'squad_size', 'average_age', 'foreigners_number',
#        'foreigners_percentage', 'national_team_players', 'stadium_name',
#        'stadium_seats', 'net_transfer_record', 'coach_name', 'last_season',
#        'filename', 'url'],
#       dtype='object')

# %%
competitions.columns
# Out:
# Index(['competition_id', 'competition_code', 'name', 'sub_type', 'type',
#        'country_id', 'country_name', 'domestic_league_code', 'confederation',
#        'url', 'is_major_national_league'],
#       dtype='object')

# %%
lineups.columns
# Out:
# Index(['game_lineups_id', 'date', 'game_id', 'player_id', 'club_id',
#        'player_name', 'type', 'position', 'number', 'team_captain'],
#       dtype='object')

# %%
games.columns
# Out:
# Index(['game_id', 'competition_id', 'season', 'round', 'date', 'home_club_id',
#        'away_club_id', 'home_club_goals', 'away_club_goals',
#        'home_club_position', 'away_club_position', 'home_club_manager_name',
#        'away_club_manager_name', 'stadium', 'attendance', 'referee', 'url',
#        'home_club_formation', 'away_club_formation', 'home_club_name',
#        'away_club_name', 'aggregate', 'competition_type'],
#       dtype='object')

# %%
transfers.columns
# Out:
# Index(['player_id', 'transfer_date', 'transfer_season', 'from_club_id',
#        'to_club_id', 'from_club_name', 'to_club_name', 'transfer_fee',
#        'market_value_in_eur', 'player_name'],
#       dtype='object')

# %%
players
# Out:
#        player_id first_name     last_name                name  last_season  \
# 0             10   Miroslav         Klose      Miroslav Klose         2015
# 1             26      Roman  Weidenfeller  Roman Weidenfeller         2017
# 2             65    Dimitar      Berbatov    Dimitar Berbatov         2015
# 3             77        NaN         Lúcio               Lúcio         2012
# 4             80        Tom        Starke          Tom Starke         2017
# ...          ...        ...           ...                 ...          ...
# 32424    1306131      Fábio         Sambú         Fábio Sambú         2024
# 32425    1306851      Hakim      Sulemana      Hakim Sulemana         2024
# 32426    1309504     Diallo      Sanoussi     Diallo Sanoussi         2024
# 32427    1309800     Issaka         Seidu        Issaka Seidu         2024
# 32428    1319047    Oğulcan         Başol       Oğulcan Başol         2024
#
# ...

# %%
players['highest_market_value_in_eur'] == players['highest_market_value_in_eur'].max()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32424    False
# 32425    False
# 32426    False
# 32427    False
# 32428    False
# Name: highest_market_value_in_eur, Length: 32429, dtype: bool

# %%
players.sort_values(by='highest_market_value_in_eur',ascending=False).head(10)
# Out:
#        player_id first_name        last_name               name  last_season  \
# 21633     418560     Erling          Haaland     Erling Haaland         2024
# 18781     342229     Kylian           Mbappé      Kylian Mbappé         2024
# 19988     371998        NaN  Vinicius Junior    Vinicius Junior         2024
# 2347       28003     Lionel            Messi       Lionel Messi         2022
# 25747     581678       Jude       Bellingham    Jude Bellingham         2024
# 5941       68290        NaN           Neymar             Neymar         2022
# 9502      134425     Raheem         Sterling    Raheem Sterling         2024
# 4314       50202       Eden           Hazard        Eden Hazard         2022
# 8980      125781    Antoine        Griezmann  Antoine Griezmann         2024
# 9424      132098      Harry             Kane         Harry Kane         2024
#
#        current_club_id        player_code country_of_birth    city_of_birth  \
# ...

# %% [markdown]
# Найти самых ценных игроков: Выведите 10 игроков с самой высокой рыночной стоимостью из таблицы players. Убедитесь, что данные отсортированы по убыванию.

# %%
club_games.columns
# Out:
# Index(['game_id', 'club_id', 'own_goals', 'own_position', 'own_manager_name',
#        'opponent_id', 'opponent_goals', 'opponent_position',
#        'opponent_manager_name', 'hosting', 'is_win'],
#       dtype='object')

# %%
clubs.columns
# Out:
# Index(['club_id', 'club_code', 'name', 'domestic_competition_id',
#        'total_market_value', 'squad_size', 'average_age', 'foreigners_number',
#        'foreigners_percentage', 'national_team_players', 'stadium_name',
#        'stadium_seats', 'net_transfer_record', 'coach_name', 'last_season',
#        'filename', 'url'],
#       dtype='object')

# %%
clubs[clubs['name'] == 'Real Madrid Club de Fútbol']
# Out:
#      club_id    club_code                        name domestic_competition_id  \
# 289      418  real-madrid  Real Madrid Club de Fútbol                     ES1
#
#      total_market_value  squad_size  average_age  foreigners_number  \
# 289                 NaN          23         27.1                 17
#
#      foreigners_percentage  national_team_players       stadium_name  \
# 289                   73.9                     16  Santiago Bernabéu
#
#      stadium_seats net_transfer_record  coach_name  last_season  \
# 289          81044            €-33.00m         NaN         2024
#
#                                               filename  \
# 289  ../data/raw/transfermarkt-scraper/2024/clubs.j...
#
#                                                    url
# 289  https://www.transfermarkt.co.uk/real-madrid/st...

# %%
club_games[club_games['club_id'] == 418]
# Out:
#         game_id  club_id  own_goals  own_position own_manager_name  \
# 477     2495361    418.0        4.0           NaN  Carlo Ancelotti
# 772     2618536    418.0        4.0           NaN   Rafael Benítez
# 1183    2878317    418.0        2.0           NaN  Zinédine Zidane
# 1272    2899910    418.0        6.0           3.0  Zinédine Zidane
# 1350    2341054    418.0        3.0           3.0  Carlo Ancelotti
# ...         ...      ...        ...           ...              ...
# 144024  4113178    418.0        1.0           1.0  Carlo Ancelotti
# 144106  3079370    418.0        1.0           2.0  Julen Lopetegui
# 144187  4405350    418.0        1.0           2.0  Carlo Ancelotti
# 144204  3079317    418.0        4.0           1.0  Julen Lopetegui
# 144674  3153158    418.0        1.0           NaN  Santiago Solari
#
#         opponent_id  opponent_goals  opponent_position opponent_manager_name  \
# 477         31614.0             0.0                NaN   Georgi Dermendzhiev
# ...

# %%
# df_combined = pd.merge(df1, df2, on='ID')

real_madrid = p.merge(clubs,club_games, on='club_id')

# %%
real_madrid = real_madrid[real_madrid['club_id'] == 418]
real_madrid
# Out:
#        club_id    club_code                        name  \
# 80299      418  real-madrid  Real Madrid Club de Fútbol
# 80300      418  real-madrid  Real Madrid Club de Fútbol
# 80301      418  real-madrid  Real Madrid Club de Fútbol
# 80302      418  real-madrid  Real Madrid Club de Fútbol
# 80303      418  real-madrid  Real Madrid Club de Fútbol
# ...        ...          ...                         ...
# 81005      418  real-madrid  Real Madrid Club de Fútbol
# 81006      418  real-madrid  Real Madrid Club de Fútbol
# 81007      418  real-madrid  Real Madrid Club de Fútbol
# 81008      418  real-madrid  Real Madrid Club de Fútbol
# 81009      418  real-madrid  Real Madrid Club de Fútbol
#
#       domestic_competition_id  total_market_value  squad_size  average_age  \
# 80299                     ES1                 NaN          23         27.1
# 80300                     ES1                 NaN          23         27.1
# ...

# %% [markdown]
# Анализ игр клуба: Используя данные из club_games и clubs, посчитайте, сколько игр выиграл каждый клуб. Создайте таблицу с названием клуба и количеством побед.
